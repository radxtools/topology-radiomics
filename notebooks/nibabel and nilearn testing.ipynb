# %% [markdown]
# coordinate system: https://nipy.org/nibabel/coordinate_systems.html
#
# neuro imaging: https://dartbrains.org/features/notebooks/3_Introduction_to_NeuroimagingData_in_Python.html
#
# neuroimaging basics: https://dartbrains.org/features/notebooks/5_Introduction_to_Neuroimaging_Data.html
#
# voxel images plotting: https://terbium.io/2017/12/matplotlib-3d/

# %%
import nibabel as nib
# Out:
# -------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-1-a6d1d588ad98> in <module>
# ----> 1 import nibabel as nib
#
# ModuleNotFoundError: No module named 'nibabel'

# %%
# !dir ""..\studies\1\data\"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 14A7-6F65
#
#  Directory of C:\Users\admin\bric-morphology\studies\1\data
#
# 08/17/2020  01:13 AM    <DIR>          .
# 08/17/2020  01:13 AM    <DIR>          ..
# 08/17/2020  12:48 AM        34,120,436 FLAIR_reg.nii
# 08/17/2020  01:13 AM        34,120,436 Lesion.nii
# 08/17/2020  12:48 AM        34,120,436 new_label.nii
# 08/17/2020  12:48 AM        34,120,436 T1_reg.nii
# 08/17/2020  12:48 AM        34,120,436 T2_reg.nii
#                5 File(s)    170,602,180 bytes
#                2 Dir(s)  102,628,958,208 bytes free

# %%
img = nib.load("../studies/1/data/FLAIR_reg.nii")
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-3-06cd82a94a04> in <module>
# ----> 1 img = nib.load("../studies/1/data/FLAIR_reg.nii")
#
# NameError: name 'nib' is not defined

# %%
img.get_data_dtype()
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-4-f72825ca6221> in <module>
# ----> 1 img.get_data_dtype()
#
# NameError: name 'img' is not defined

# %%
type(img.get_fdata())
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-5-4d14ecdbd8bc> in <module>
# ----> 1 type(img.get_fdata())
#
# NameError: name 'img' is not defined

# %%
img.affine, 
x,y,z = img.shape
data = img.get_fdata()
data,img.shape
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-6-38e6ac7c0098> in <module>
# ----> 1 img.affine,
#       2 x,y,z = img.shape
#       3 data = img.get_fdata()
#       4 data,img.shape
#
# NameError: name 'img' is not defined

# %%
print(img.header)
img.affine
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-7-02d3e7447349> in <module>
# ----> 1 print(img.header)
#       2 img.affine
#
# NameError: name 'img' is not defined

# %%
import matplotlib.pyplot as plt
def show_slices(slices):
    """ Function to display row of image slices """
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")

slice_0 = data[x//2, :, :]
slice_1 = data[:, y//2, :]
slice_2 = data[:, :, z//2]
show_slices([slice_0, slice_1, slice_2])
plt.suptitle("Center slices for EPI image")
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-8-67463977a8b4> in <module>
#       6         axes[i].imshow(slice.T, cmap="gray", origin="lower")
#       7
# ----> 8 slice_0 = data[x//2, :, :]
#       9 slice_1 = data[:, y//2, :]
#      10 slice_2 = data[:, :, z//2]
#
# NameError: name 'data' is not defined

# %%
from nilearn import plotting
img.shape
x//2, y//2, z//2
# Out:
# (96, 114, 96)

# %%
plotting.plot_epi(img)

# %%
plotting.plot_glass_brain(img, cut_coords=(0,0,0))

# %%
plotting.plot_img(img)

# %%
from nilearn.plotting import view_img, plot_glass_brain, plot_anat, plot_epi

# %%
plot_anat(img, draw_cross=False, display_mode='y')

# %%
plot_anat(img, draw_cross=False, display_mode='x')

# %%
plot_anat(img, draw_cross=False, display_mode='z')

# %%
from itkwidgets import view

# %%
view(data)
# Out:
# Viewer(geometries=[], gradient_opacity=0.22, point_sets=[], rendered_image=<itk.itkImagePython.itkImageD3; pro…
